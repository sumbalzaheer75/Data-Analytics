# %% [markdown]
# ## ***1.Display Top 10 Rows of The Dataset***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('adult.csv')

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# ## ***2. Check Last 10 Rows of The Dataset***

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# ## ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# ## ***4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.count()
# Out:
# age                48842
# workclass          48842
# fnlwgt             48842
# education          48842
# educational-num    48842
# marital-status     48842
# occupation         48842
# relationship       48842
# race               48842
# gender             48842
# capital-gain       48842
# capital-loss       48842
# hours-per-week     48842
# native-country     48842
# income             48842
# dtype: int64

# %% [markdown]
# ## ***5.Check Null Values And Also Create A Heatmap In The Dataset***

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar = False, cmap= 'viridis')
plt.title('Heatmap Of Missing Values')
plt.show()

# %% [markdown]
# ## ***6. Fetch Random Sample From the Dataset (50%)***

# %%
df.sample(frac=0.5)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 8343    71           Private   99549       5th-6th                3
# 37727   29           Private  178649       HS-grad                9
# 11420   18           Private  187722  Some-college               10
# 32260   48           Private  120724          12th                8
# 3115    33      Self-emp-inc  218164  Some-college               10
# ...    ...               ...     ...           ...              ...
# 28878   57           Private  180779     Bachelors               13
# 29252   17           Private  218124          11th                7
# 27646   18           Private   28648          11th                7
# 11789   69  Self-emp-not-inc  165814  Some-college               10
# 9615    48           Private  168038  Some-college               10
#
#               marital-status       occupation    relationship   race  gender  \
# ...

# %% [markdown]
# ## ***7. Perform Data Cleaning [Replace'?' with NaN]***

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mask = df.applymap(lambda x: x == '?')
locations = df[mask.any(axis=1)]
print(locations)
# Out:
#        age         workclass   fnlwgt     education  educational-num  \
# 4       18                 ?   103497  Some-college               10
# 6       29                 ?   227026       HS-grad                9
# 13      58                 ?   299831       HS-grad                9
# 19      40           Private    85019     Doctorate               16
# 22      72                 ?   132015       7th-8th                4
# 35      65                 ?   191846       HS-grad                9
# 65      41           Private   109912     Bachelors               13
# 75      17                 ?   165361          10th                6
# 83      44      Self-emp-inc   223881       HS-grad                9
# 89      41                 ?    38434       Masters               14
# 100     51                 ?   189762  Some-college               10
# 113     20                 ?    30796       HS-grad                9
# 132     20                 ?   334105       HS-grad                9
# ...

# %%
df.replace('?', np.nan, inplace=True)

# %%
print(df.isnull().sum())

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar = False, cmap= 'viridis')
plt.title('Heatmap Of Missing Values')
plt.show()

# %% [markdown]
# ## ***8. Drop All The Missing Values***

# %%
print(df.isnull().sum())

# %%
df = df.dropna()    # Dropping the missing values.
df.count()

# %%
print(df.isnull().sum())

# %% [markdown]
# ## ***9. Check Duplicate Data and Drop Them***

# %%
df.duplicated()

# %%
df[df.duplicated()]

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)

# %%
df.count()

# %%
df = df.drop_duplicates()
df

# %%
df.count()

# %% [markdown]
# ## ***10. Get Overall Statistics About The Dataframe***

# %%
df.describe()

# %% [markdown]
# ## ***11. Drop The Columns education-num, capital-gain and capital-loss***

# %%
df.drop(['educational-num', 'capital-gain', 'capital-loss'], axis=1, inplace=True)
df

# %% [markdown]
# ## ***12. What Is The Distribution of Age Column Show In Graph?***

# %%
sns.boxplot(x=df['age'])

# %%
sns.histplot(df['age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

# %% [markdown]
# ## ***13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method And Also Without Using Between Method***

# %%
age_filter = df['age'].between(17, 48, inclusive='both')
total_counts = df[age_filter].shape[0]

# %%
total_counts

# %%
age_filter= (df['age']>=17) & (df['age']<=48)
total_count = df[age_filter].shape[0]

# %%
total_count

# %% [markdown]
# ## ***14. What is The Distribution of Workclass Column***

# %%
df.workclass.value_counts().plot(kind='bar', color='skyblue', figsize=(10,5))
plt.title("Distribution of WorkClass")
plt.xlabel('WorkClass')
plt.ylabel('Frequency')
plt.show()

# %%
df.workclass.value_counts()

# %% [markdown]
# ## ***15. How Many Person Having Bachelors or Masters Degree***

# %%
degree_filter = df['education'].isin(['Bachelors', 'Masters'])
total_persons = df[degree_filter].shape[0]
total_persons

# %% [markdown]
# ## ***16. Create A Boxplot Of The "Income" Column Against The "Age" Column, Segmented By Gender***

# %%
sns.boxplot(data = df, x='age', y='income', hue='gender', palette='Set2')
plt.title("Income vs Age by Gender")
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ## ***17. Replace income value [<=50k with 0 and >50k with 1]***

# %%
df['income'] = df['income'].replace({'<=50K':0,'>50K':1})

# %%
print(df['income'].unique())

# %%
df.head()

# %% [markdown]
# ## ***18. Which Workclass getting The Highest Salary***

# %%
highest_salary_workclass = df.groupby('workclass')['income'].mean()
highest_salary_workclass_name = highest_salary_workclass.idxmax()
print(highest_salary_workclass_name)
highest_salary_value = highest_salary_workclass.max()
print(highest_salary_value)

# %% [markdown]
# ## ***19. Who Has Better Chance To Get Salary >50k Male or Female***

# %%
gender_income = df.groupby('gender')['income'].mean()
male = gender_income['Male']*100
female = gender_income['Female']*100
print(f"Percentage of Males earning >50K: {male:.2f}%")
print(f"Percentage of Females earning >50K: {female:.2f}%")
if male > female:
    print('Males have better chance to get salary >50k')
elif female>male:
    print('Females have better chance to get salary >50k')
else:
    print('Both have equal chance to get salary >50k')

# %% [markdown]
# ## ***20. Convert Workclass Column DataType To Category Datatype***

# %%
df.columns

# %%
df['workclass'] = df['workclass'].astype('category')

# %%
print(df['workclass'].dtypes)
